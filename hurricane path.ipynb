# %%
import geopandas as gpd 

LA = gpd.read_file(r"C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\tl_2016_22_cousub\tl_2016_22_cousub.shp")

# %%
LA.to_crs(epsg = 4326)
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10,10))
LA.plot(ax=ax, **{'edgecolor':'black', 'facecolor':'white'})
LA.centroid.plot(ax=ax, c='black')
# Out:
# C:\Users\ta444503\AppData\Local\Temp/ipykernel_9464/1069488851.py:5: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   LA.centroid.plot(ax=ax, c='black')
# <AxesSubplot:>

# %%
LA.head()
# Out:
#   STATEFP COUNTYFP COUSUBFP  COUSUBNS       GEOID NAME     NAMELSAD LSAD  \
# 0      22      061    95577  02405103  2206195577   11  District 11   28
# 1      22      027    94966  01930128  2202794966    6   District 6   28
# 2      22      027    95380  01930267  2202795380    9   District 9   28
# 3      22      045    95491  01929781  2204595491   10  District 10   28
# 4      22      045    95629  01929825  2204595629   12  District 12   28
#
#   CLASSFP  MTFCC CNECTAFP NECTAFP NCTADVFP FUNCSTAT      ALAND      AWATER  \
# 0      Z1  G4040     None    None     None        N   43237655       90120
# 1      Z1  G4040     None    None     None        N  289510157      253256
# 2      Z1  G4040     None    None     None        N   43297300    23037390
# 3      Z1  G4040     None    None     None        N  501595099  1087274876
# 4      Z1  G4040     None    None     None        N  122905501     1322999
#
#       INTPTLAT      INTPTLON  \
# 0  +32.4777661  -092.6745118
# ...

# %%
centroid = LA.centroid
center = gpd.GeoDataFrame()
center['Point'] = centroid
# Out:
# C:\Users\ta444503\AppData\Local\Temp/ipykernel_9464/662377897.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = LA.centroid

# %%
#center.someattribute
center['lon'] = center.Point.x
center['lat'] = center.Point.y

# %%
import pandas as pd

# %%
fig, ax = plt.subplots(1,figsize=(10,10))
LA.plot(ax=ax, cmap='BuGn')

track = pd.read_csv(r"C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\Data\Ida Track Path.csv")
track["Longitude (W)"]=track["Longitude (W)"]*(-1)
x = track["Latitude (N)"].to_list()
y = track["Longitude (W)"].to_list()
plt.plot(y,x,'o-', linewidth=1, markersize = 10)

# %%
fig, ax = plt.subplots(1,figsize=(10,10))
LA.plot(ax=ax, linewidth=0.1, edgecolor= 'white')
track = pd.read_csv(r"C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\Data\Ida Track for Gif.csv")

track["Longitude (W)"]=track["Longitude (W)"]*(-1)
x = track["Latitude (N)"].to_list()
y = track["Longitude (W)"].to_list()
plt.plot(y[3:8],x[3:8],'o-', linewidth=4, markersize = 12, label='Ida path with time and speed', color ='black')
plt.legend(loc='upper right')

ax.annotate('8/29 (4.55 pm); 130 mph',xy=(0.6,0.12), xycoords='figure fraction', horizontalalignment='left', verticalalignment='top', fontsize=12, color='black')
ax.annotate('8/29 (6 pm); 125 mph',xy=(0.57,0.16), xycoords='figure fraction', horizontalalignment='left', verticalalignment='top', fontsize=12, color='black')
ax.annotate('8/30 (12 am); 105 mph',xy=(0.55,0.26), xycoords='figure fraction', horizontalalignment='left', verticalalignment='top', fontsize=12, color='black')
ax.annotate('8/30 (6 am); 65 mph',xy=(0.53,0.37), xycoords='figure fraction', horizontalalignment='left', verticalalignment='top', fontsize=12, color='black')
ax.annotate('8/30 (12 pm); 40 mph',xy=(0.51,0.51), xycoords='figure fraction', horizontalalignment='left', verticalalignment='top', fontsize=12, color='black')
# Out:
# Text(0.51, 0.51, '8/30 (12 pm); 40 mph')

# %%
LAP = gpd.read_file(r'C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\LA Parishes\BNDY_DOTD_ParishBoundaries.shp')

# %%
fig, ax = plt.subplots(1,figsize=(10,10))
LAP.plot(ax=ax, linewidth=0.1, edgecolor= 'white')
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(1,figsize=(10,10))
LAP.plot(ax=ax, linewidth=0.1, edgecolor= 'white')
track = pd.read_csv(r"C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\Data\Ida Track for Gif.csv")

track["Longitude (W)"]=track["Longitude (W)"]*(-1)
x = track["Latitude (N)"].to_list()
y = track["Longitude (W)"].to_list()
plt.plot(y[3:8],x[3:8],'o-', linewidth=4, markersize = 12, label='Ida path with time and speed',color ='black')
plt.legend(loc='upper right')
ax.annotate('8/29 (4.55 pm); 130 mph',xy=(0.6,0.12), xycoords='figure fraction', horizontalalignment='left', verticalalignment='top', fontsize=12, color='black')
ax.annotate('8/29 (6 pm); 125 mph',xy=(0.57,0.16), xycoords='figure fraction', horizontalalignment='left', verticalalignment='top', fontsize=12, color='black')
ax.annotate('8/30 (12 am); 105 mph',xy=(0.55,0.26), xycoords='figure fraction', horizontalalignment='left', verticalalignment='top', fontsize=12, color='black')
ax.annotate('8/30 (6 am); 65 mph',xy=(0.53,0.37), xycoords='figure fraction', horizontalalignment='left', verticalalignment='top', fontsize=12, color='black')
ax.annotate('8/30 (12 pm); 40 mph',xy=(0.51,0.51), xycoords='figure fraction', horizontalalignment='left', verticalalignment='top', fontsize=12, color='black')
# Out:
# Text(0.51, 0.51, '8/30 (12 pm); 40 mph')

# %%
import numpy as np
# vectorized haversine function
def haversine(lat1, lon1, lat2, lon2, to_radians=True, earth_radius=6371):
    """
    slightly modified version: of http://stackoverflow.com/a/29546836/2901002

    Calculate the great circle distance between two points
    on the earth (specified in decimal degrees or in radians)

    All (lat, lon) coordinates must have numeric dtypes and be of equal length.

    """
    if to_radians:
        lat1, lon1, lat2, lon2 = np.radians([lat1, lon1, lat2, lon2])

    a = np.sin((lat2-lat1)/2.0)**2 + \
        np.cos(lat1) * np.cos(lat2) * np.sin((lon2-lon1)/2.0)**2

    return earth_radius * 2 * np.arcsin(np.sqrt(a))


#dist = \
#    haversine(28.9, -94.5,
#                 33, -88)

# %%
dict = {}
#for (a, b) in zip(x,y):
for (c,d) in zip(center['lat'],center['lon']):
    dist = haversine(c,d,16.5, -78.9)
    dict[c,d] = dist
        
'''
activ_power_road_wind['dist'] = \
    haversine(activ_power_road_wind['Latitude (N)'], activ_power_road_wind['Longitude (W)'],
                 activ_power_road_wind['lat'], activ_power_road_wind['lon'])
'''
# Out:
# "\nactiv_power_road_wind['dist'] =     haversine(activ_power_road_wind['Latitude (N)'], activ_power_road_wind['Longitude (W)'],\n                 activ_power_road_wind['lat'], activ_power_road_wind['lon'])\n"

# %%
haversine(16.5, -78.9,32.47976,-92.68562)
# Out:
# 2254.1210943219985

# %%
len(dict)
# Out:
# 579

# %%
dict = {}
#for (a, b) in zip(x,y):
for (c,d) in zip(center['lat'],center['lon']):
    dist = haversine(c,d,18.3, -80.2)
    dict[c,d] = dist

# %%
dict
# Out:
# {(32.47975583913678, -92.68561536407614): 2011.0940021036997,
#  (32.69725523842147, -92.89811864223103): 2042.4008195377885,
#  (32.772610501954915, -92.97610143189087): 2053.509653946303,
#  (29.598742067784034, -91.8282242871047): 1722.439286761882,
#  (29.869188137930063, -91.74601755308686): 1737.9444326607595,
#  (31.390135233520244, -93.59566359446042): 1982.6948382500432,
#  (31.53008917740372, -93.55288593431183): 1990.6572696407582,
#  (31.661379732273968, -93.59559403905398): 2003.7866048360183,
#  (32.48658621681325, -93.10672101971552): 2038.0375681508713,
#  (32.22605177762735, -93.11178373266978): 2017.0622650761559,
#  (32.49477674019752, -92.98900395807813): 2031.287543433539,
#  (32.29606447222448, -93.27264599262764): 2033.0792009522381,
#  (29.95867452705288, -89.95796464940823): 1629.5224346708621,
#  (29.939423620599218, -89.9038486857981): 1624.557108623897,
#  (29.965133373827907, -89.98271751664477): 1631.5940388378508,
# ...

# %%
'''dict2 = {}
dis = []
for (a, b) in zip(x,y):
    for (c,d) in zip(center['lat'],center['lon']):
        dis.append(haversine(c,d,16.5, -78.9))
        #dict2[c,d] = dist
'''
# Out:
# "dict2 = {}\ndis = []\nfor (a, b) in zip(x,y):\n    for (c,d) in zip(center['lat'],center['lon']):\n        dis.append(haversine(c,d,16.5, -78.9))\n        #dict2[c,d] = dist\n"

# %%
len(dis)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_34152/1924992835.py in <module>
# ----> 1 len(dis)
#
# NameError: name 'dis' is not defined

# %%
haversine(17.4, -78.9,32.47976,-92.68562)
# Out:
# 2173.3538094329824

# %%
dis3 = []
for (a, b) in zip(center['lat'],center['lon']):
    for (c,d) in zip(x,y):
        dis3.append(haversine(c,d,a,b))
        #dict2[c,d] = dist

# %%
dis3
# Out:
# [2254.120459745776,
#  2135.6024481692516,
#  2011.0940021036997,
#  1868.9030137737768,
#  1729.762665443517,
#  1575.834443554668,
#  1458.756304157138,
#  1422.3290530983593,
#  1268.5688531332012,
#  1127.8769879120825,
#  966.6122709199736,
#  808.9541285088669,
#  664.3900259355064,
#  532.1364416717998,
#  444.49055849577667,
#  424.95736411660624,
#  348.7537005598296,
#  274.981783924647,
#  200.56191621831795,
#  207.67200499464442,
#  257.7521461281915,
#  339.2923062669403,
#  451.2915135686521,
#  592.5841048874391,
#  757.0768875707686,
#  954.3077746345085,
#  1170.401756489592,
#  1468.83132120231,
#  1732.6550628069267,
#  1986.4833791456333,
#  2261.3787528573757,
#  2525.067582676419,
#  2793.238601769096,
#  2921.4515571057773,
#  3022.6155363455387,
#  3091.7213253712143,
#  3054.437924950169,
#  2996.8172091201372,
#  2939.887990975024,
#  2928.5325301434295,
#  2285.429646386158,
#  2166.9085265221365,
#  2042.4008195377885,
#  1900.201882479452,
# ...

# %%
len(dis3)
# Out:
# 23160

# %%
min(dis3[:40])
# Out:
# 200.56191621831795

# %%
len(dis3[:40])
# Out:
# 40

# %%
x = list(range(0,23161,40))
y = x[1:]

# %%
janina = []
for i, j in zip(list(range(0,23160,40)),y):
    janina.append(min(dis3[i:j]))

# %%
y
# Out:
# [40,
#  80,
#  120,
#  160,
#  200,
#  240,
#  280,
#  320,
#  360,
#  400,
#  440,
#  480,
#  520,
#  560,
#  600,
#  640,
#  680,
#  720,
#  760,
#  800,
#  840,
#  880,
#  920,
#  960,
#  1000,
#  1040,
#  1080,
#  1120,
#  1160,
#  1200,
#  1240,
#  1280,
#  1320,
#  1360,
#  1400,
#  1440,
#  1480,
#  1520,
#  1560,
#  1600,
#  1640,
#  1680,
#  1720,
#  1760,
#  1800,
#  1840,
#  1880,
#  1920,
#  1960,
#  2000,
#  2040,
#  2080,
#  2120,
#  2160,
#  2200,
#  2240,
#  2280,
#  2320,
#  2360,
#  2400,
#  2440,
#  2480,
#  2520,
#  2560,
#  2600,
#  2640,
#  2680,
#  2720,
#  2760,
#  2800,
#  2840,
#  2880,
#  2920,
#  2960,
#  3000,
#  3040,
#  3080,
#  3120,
#  3160,
#  3200,
#  3240,
#  3280,
#  3320,
#  3360,
#  3400,
#  3440,
#  3480,
#  3520,
#  3560,
#  3600,
#  3640,
#  3680,
#  3720,
#  3760,
#  3800,
#  3840,
#  3880,
#  3920,
#  3960,
#  4000,
#  4040,
#  4080,
#  4120,
#  4160,
#  4200,
#  4240,
#  4280,
#  4320,
#  4360,
#  4400,
#  4440,
#  4480,
#  4520,
#  4560,
# ...

# %%
janina
# Out:
# [200.56191621831795,
#  230.5320844178153,
#  240.80894573238137,
#  123.21290098392288,
#  110.53953715323856,
#  256.00904845954625,
#  251.4937850883084,
#  255.96960045379046,
#  235.24268981922154,
#  223.93214157398583,
#  225.91929561155297,
#  240.83473244878104,
#  62.21342100262026,
#  67.2348482567629,
#  59.922404734751446,
#  125.19793527123028,
#  236.54775392012047,
#  243.75616808642704,
#  253.9437117315874,
#  261.24820763900874,
#  261.29088412628164,
#  244.6919828855573,
#  118.67100757335426,
#  120.99727404444107,
#  117.73982706499582,
#  115.77863506987119,
#  119.32006674470676,
#  111.1484978586388,
#  157.81418063138844,
#  169.08866238592194,
#  168.05936438301168,
#  163.12675354142013,
#  114.63426439223835,
#  117.89070495101294,
#  195.50044484192938,
#  181.54108756457862,
#  180.16671244073476,
#  183.8927958570243,
#  182.92203149958596,
#  121.6469670011942,
#  130.5585179284987,
#  203.9108298043143,
#  214.45691411948792,
#  217.40028837072475,
# ...

# %%
len(janina)
# Out:
# 579

# %%
min(janina)
# Out:
# 5.7346072103011485

# %%
max(janina)
# Out:
# 317.49928855263073

# %%
avg(janina)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_34152/4191197205.py in <module>
# ----> 1 avg(janina)
#
# NameError: name 'avg' is not defined

# %%
LA['Distance_to_hurr_path'] = janina

# %%
LA.head()
# Out:
#   STATEFP COUNTYFP COUSUBFP  COUSUBNS       GEOID NAME     NAMELSAD LSAD  \
# 0      22      061    95577  02405103  2206195577   11  District 11   28
# 1      22      027    94966  01930128  2202794966    6   District 6   28
# 2      22      027    95380  01930267  2202795380    9   District 9   28
# 3      22      045    95491  01929781  2204595491   10  District 10   28
# 4      22      045    95629  01929825  2204595629   12  District 12   28
#
#   CLASSFP  MTFCC CNECTAFP NECTAFP NCTADVFP FUNCSTAT      ALAND      AWATER  \
# 0      Z1  G4040     None    None     None        N   43237655       90120
# 1      Z1  G4040     None    None     None        N  289510157      253256
# 2      Z1  G4040     None    None     None        N   43297300    23037390
# 3      Z1  G4040     None    None     None        N  501595099  1087274876
# 4      Z1  G4040     None    None     None        N  122905501     1322999
#
#       INTPTLAT      INTPTLON  \
# 0  +32.4777661  -092.6745118
# ...

# %%
cou_fip = pd.read_csv(r"C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\county_fips_master.csv")

# %%
loui = cou_fip[cou_fip['state_abbr'] == 'LA']

# %%
loui.head()
# Out:
#        fips        county_name state_abbr state_name             long_name  \
# 1115  22001      Acadia Parish         LA  Louisiana      Acadia Parish LA
# 1116  22003       Allen Parish         LA  Louisiana       Allen Parish LA
# 1117  22005   Ascension Parish         LA  Louisiana   Ascension Parish LA
# 1118  22007  Assumption Parish         LA  Louisiana  Assumption Parish LA
# 1119  22009   Avoyelles Parish         LA  Louisiana   Avoyelles Parish LA
#
#       sumlev  region  division  state  county crosswalk region_name  \
# 1115    50.0     3.0       7.0   22.0     1.0  3-7-22-1       South
# 1116    50.0     3.0       7.0   22.0     3.0  3-7-22-3       South
# 1117    50.0     3.0       7.0   22.0     5.0  3-7-22-5       South
# 1118    50.0     3.0       7.0   22.0     7.0  3-7-22-7       South
# 1119    50.0     3.0       7.0   22.0     9.0  3-7-22-9       South
#
#            division_name
# 1115  West South Central
# 1116  West South Central
# 1117  West South Central
# ...

# %%
loui['fips'] = loui['fips'].apply(str)
# Out:
# C:\Users\ta444503\AppData\Local\Temp/ipykernel_34152/1686277650.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loui['fips'] = loui['fips'].apply(str)

# %%
loui.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64 entries, 1115 to 1178
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   fips           64 non-null     object
#  1   county_name    64 non-null     object
#  2   state_abbr     64 non-null     object
#  3   state_name     64 non-null     object
#  4   long_name      64 non-null     object
#  5   sumlev         64 non-null     float64
#  6   region         64 non-null     float64
#  7   division       64 non-null     float64
#  8   state          64 non-null     float64
#  9   county         64 non-null     float64
#  10  crosswalk      64 non-null     object
#  11  region_name    64 non-null     object
#  12  division_name  64 non-null     object
# dtypes: float64(5), object(8)
# memory usage: 7.0+ KB

# %%
loui['fips'] = loui['fips'].str[2:]
# Out:
# C:\Users\ta444503\AppData\Local\Temp/ipykernel_34152/1855074350.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loui['fips'] = loui['fips'].str[2:]

# %%
loui.head()
# Out:
#      fips        county_name state_abbr state_name             long_name  \
# 1115  001      Acadia Parish         LA  Louisiana      Acadia Parish LA
# 1116  003       Allen Parish         LA  Louisiana       Allen Parish LA
# 1117  005   Ascension Parish         LA  Louisiana   Ascension Parish LA
# 1118  007  Assumption Parish         LA  Louisiana  Assumption Parish LA
# 1119  009   Avoyelles Parish         LA  Louisiana   Avoyelles Parish LA
#
#       sumlev  region  division  state  county crosswalk region_name  \
# 1115    50.0     3.0       7.0   22.0     1.0  3-7-22-1       South
# 1116    50.0     3.0       7.0   22.0     3.0  3-7-22-3       South
# 1117    50.0     3.0       7.0   22.0     5.0  3-7-22-5       South
# 1118    50.0     3.0       7.0   22.0     7.0  3-7-22-7       South
# 1119    50.0     3.0       7.0   22.0     9.0  3-7-22-9       South
#
#            division_name
# 1115  West South Central
# 1116  West South Central
# 1117  West South Central
# ...

# %%
#loui['county_name'] = loui['county_name'].str.replace(' Parish', '')

# %%
loui.rename(columns={'fips':'COUNTYFP'}, inplace=True)
# Out:
# C:\Users\ta444503\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
louisiana = loui[['COUNTYFP','county_name']]

# %%
merged = LA.merge(louisiana)

# %%
merged.loc[merged['NAMELSAD'] == 'New Orleans city', 'NAMELSAD'] = 'New Orleans'

# %%
merged
# Out:
#     STATEFP COUNTYFP COUSUBFP  COUSUBNS       GEOID         NAME     NAMELSAD  \
# 0        22      061    95577  02405103  2206195577           11  District 11
# 1        22      061    95508  02405102  2206195508           10  District 10
# 2        22      061    94465  01929961  2206194465            3   District 3
# 3        22      061    94642  01930020  2206194642            4   District 4
# 4        22      061    94080  02405101  2206194080            1   District 1
# ..      ...      ...      ...       ...         ...          ...          ...
# 574      22      093    95191  01930205  2209395191            7   District 7
# 575      22      093    94876  01930097  2209394876            5   District 5
# 576      22      093    94318  01929913  2209394318            2   District 2
# 577      22      093    94678  01930032  2209394678            4   District 4
# 578      22      071    98000  00545142  2207198000  New Orleans  New Orleans
#
# ...

# %%
merged['County_subdivision'] = merged['NAMELSAD'] + ', ' + merged['county_name']

# %%
merged
# Out:
#     STATEFP COUNTYFP COUSUBFP  COUSUBNS       GEOID         NAME     NAMELSAD  \
# 0        22      061    95577  02405103  2206195577           11  District 11
# 1        22      061    95508  02405102  2206195508           10  District 10
# 2        22      061    94465  01929961  2206194465            3   District 3
# 3        22      061    94642  01930020  2206194642            4   District 4
# 4        22      061    94080  02405101  2206194080            1   District 1
# ..      ...      ...      ...       ...         ...          ...          ...
# 574      22      093    95191  01930205  2209395191            7   District 7
# 575      22      093    94876  01930097  2209394876            5   District 5
# 576      22      093    94318  01929913  2209394318            2   District 2
# 577      22      093    94678  01930032  2209394678            4   District 4
# 578      22      071    98000  00545142  2207198000  New Orleans  New Orleans
#
# ...

# %%
res = pd.read_csv(r"C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\Data\resilience\resilience_166countysubdivision.csv")

# %%
merged2 = merged.merge(res, on = ['County_subdivision'])

# %%
merged2
# Out:
#     STATEFP COUNTYFP COUSUBFP  COUSUBNS       GEOID         NAME     NAMELSAD  \
# 0        22      045    95629  01929825  2204595629           12  District 12
# 1        22      045    94060  01929738  2204594060            1   District 1
# 2        22      045    94990  01930136  2204594990            6   District 6
# 3        22      045    95677  01929841  2204595677           13  District 13
# 4        22      045    94444  01929954  2204594444            3   District 3
# ..      ...      ...      ...       ...         ...          ...          ...
# 161      22      093    95191  01930205  2209395191            7   District 7
# 162      22      093    94876  01930097  2209394876            5   District 5
# 163      22      093    94318  01929913  2209394318            2   District 2
# 164      22      093    94678  01930032  2209394678            4   District 4
# 165      22      071    98000  00545142  2207198000  New Orleans  New Orleans
#
# ...

# %%
merged2.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166 entries, 0 to 165
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   County_subdivision  166 non-null    object
#  1   Loss_of_Resilience  166 non-null    float64
#  2   Resilience          166 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 4.0+ KB

# %%
df20 = merged2[['Distance_to_hurr_path','County_subdivision','Loss_of_Resilience', 'Resilience']]

# %%
pd.set_option('display.max_rows', None)
# Out:
#                        Distance_to_hurr_path  Loss_of_Resilience  Resilience
# Distance_to_hurr_path               1.000000            0.134549    0.134549
# Loss_of_Resilience                  0.134549            1.000000    1.000000
# Resilience                          0.134549            1.000000    1.000000

# %%
df20['abs_loss_of_resilience'] = 36 - df20['Resilience']
# Out:
# C:\Users\ta444503\AppData\Local\Temp/ipykernel_3144/202275312.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df20['abs_loss_of_resilience'] = 36 - df20['Resilience']

# %%
df20
# Out:
#      Distance_to_hurr_path                       County_subdivision  \
# 0               110.539537               District 12, Iberia Parish
# 1               118.671008                District 1, Iberia Parish
# 2               115.778635                District 6, Iberia Parish
# 3               129.132666               District 13, Iberia Parish
# 4               121.246905                District 3, Iberia Parish
# 5               121.161052                District 5, Iberia Parish
# 6               236.547754                District 1, Sabine Parish
# 7                62.213421           District B, St. Bernard Parish
# 8                67.234848           District D, St. Bernard Parish
# 9                59.922405           District A, St. Bernard Parish
# 10              125.197935           District E, St. Bernard Parish
# 11               63.515209           District C, St. Bernard Parish
# 12              157.814181                District 1, Acadia Parish
# ...

# %%
df20.corr()
# Out:
#                         Distance_to_hurr_path  Loss_of_Resilience  Resilience  \
# Distance_to_hurr_path                1.000000            0.134549    0.134549
# Loss_of_Resilience                   0.134549            1.000000    1.000000
# Resilience                           0.134549            1.000000    1.000000
# abs_loss_of_resilience              -0.134549           -1.000000   -1.000000
#
#                         abs_loss_of_resilience
# Distance_to_hurr_path                -0.134549
# Loss_of_Resilience                   -1.000000
# Resilience                           -1.000000
# abs_loss_of_resilience                1.000000

# %%
df20.describe()
# Out:
#        Distance_to_hurr_path  Loss_of_Resilience  Resilience  \
# count             166.000000          166.000000  166.000000
# mean               67.630501           -3.189836   32.810164
# std                55.064340            2.815119    2.815119
# min                 5.734607          -12.881592   23.118408
# 25%                30.813516           -4.684079   31.315921
# 50%                49.067858           -2.278196   33.721804
# 75%                87.523734           -1.038939   34.961061
# max               287.376899           -0.100935   35.899065
#
#        abs_loss_of_resilience
# count              166.000000
# mean                 3.189836
# std                  2.815119
# min                  0.100935
# 25%                  1.038939
# 50%                  2.278196
# 75%                  4.684079
# max                 12.881592

# %%
df20.to_csv(r"C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\Data\output from path data\hur_path_merges.csv",index=False)

# %% [markdown]
# # this is trial for another way

# %%
dis4 = []
for (a, b) in zip(center['lat'],center['lon']):
    dis4.append(haversine(29.1,-90.2,a,b))
        #dict2[c,d] = dist

# %%
len(dis4)
# Out:
# 579

# %%
LA['distance'] = dis4

# %%
cou_fip = pd.read_csv(r"C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\county_fips_master.csv")

# %%
loui = cou_fip[cou_fip['state_abbr'] == 'LA']

# %%
loui['fips'] = loui['fips'].apply(str)
# Out:
# C:\Users\ta444503\AppData\Local\Temp/ipykernel_9464/1686277650.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loui['fips'] = loui['fips'].apply(str)

# %%
loui.head()
# Out:
#      fips        county_name state_abbr state_name             long_name  \
# 1115  001      Acadia Parish         LA  Louisiana      Acadia Parish LA
# 1116  003       Allen Parish         LA  Louisiana       Allen Parish LA
# 1117  005   Ascension Parish         LA  Louisiana   Ascension Parish LA
# 1118  007  Assumption Parish         LA  Louisiana  Assumption Parish LA
# 1119  009   Avoyelles Parish         LA  Louisiana   Avoyelles Parish LA
#
#       sumlev  region  division  state  county crosswalk region_name  \
# 1115    50.0     3.0       7.0   22.0     1.0  3-7-22-1       South
# 1116    50.0     3.0       7.0   22.0     3.0  3-7-22-3       South
# 1117    50.0     3.0       7.0   22.0     5.0  3-7-22-5       South
# 1118    50.0     3.0       7.0   22.0     7.0  3-7-22-7       South
# 1119    50.0     3.0       7.0   22.0     9.0  3-7-22-9       South
#
#            division_name
# 1115  West South Central
# 1116  West South Central
# 1117  West South Central
# ...

# %%
loui['fips'] = loui['fips'].str[2:]
# Out:
# C:\Users\ta444503\AppData\Local\Temp/ipykernel_9464/1855074350.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loui['fips'] = loui['fips'].str[2:]

# %%
loui['county_name'] = loui['county_name'].str.replace(' Parish', '')
# Out:
# C:\Users\ta444503\AppData\Local\Temp/ipykernel_9464/1130562991.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loui['county_name'] = loui['county_name'].str.replace(' Parish', '')

# %%
loui.rename(columns={'fips':'COUNTYFP'}, inplace=True)
# Out:
# C:\Users\ta444503\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
louisiana = loui[['COUNTYFP','county_name']]
merged = LA.merge(louisiana)

# %%
merged.loc[merged['NAMELSAD'] == 'New Orleans city', 'NAMELSAD'] = 'New Orleans'
merged['County_subdivision'] = merged['NAMELSAD'] + ', ' + merged['county_name']

# %%
res = pd.read_csv(r"C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\Data\merged dataset\data_for_R3.csv")

# %%
res['County_subdivision'] = res['County_subdivision'].str.replace(' Parish', '')

# %%
merged4 = merged.merge(res)

# %%
merged4
# Out:
#     STATEFP COUNTYFP COUSUBFP  COUSUBNS       GEOID         NAME     NAMELSAD  \
# 0        22      045    95629  01929825  2204595629           12  District 12
# 1        22      045    94060  01929738  2204594060            1   District 1
# 2        22      045    94990  01930136  2204594990            6   District 6
# 3        22      045    95677  01929841  2204595677           13  District 13
# 4        22      045    94444  01929954  2204594444            3   District 3
# ..      ...      ...      ...       ...         ...          ...          ...
# 161      22      093    95191  01930205  2209395191            7   District 7
# 162      22      093    94876  01930097  2209394876            5   District 5
# 163      22      093    94318  01929913  2209394318            2   District 2
# 164      22      093    94678  01930032  2209394678            4   District 4
# 165      22      071    98000  00545142  2207198000  New Orleans  New Orleans
#
# ...

# %%
merged4.columns
# Out:
# Index(['STATEFP', 'COUNTYFP', 'COUSUBFP', 'COUSUBNS', 'GEOID', 'NAME',
#        'NAMELSAD', 'LSAD', 'CLASSFP', 'MTFCC', 'CNECTAFP', 'NECTAFP',
#        'NCTADVFP', 'FUNCSTAT', 'ALAND', 'AWATER', 'INTPTLAT', 'INTPTLON',
#        'geometry', 'distance', 'county_name', 'County_subdivision', 'a', 'Y',
#        'b', 'c', 'd', 'e', 'f', 'sub', 'County', 'coun', 'Housings',
#        'House_age', 'Hispanic'],
#       dtype='object')

# %%
merged5 = merged4[['County_subdivision', 'a', 'Y',
       'b', 'c', 'd', 'e', 'f', 'sub', 'County', 'coun', 'Housings',
       'House_age', 'Hispanic','distance']]

# %%
merged5
# Out:
#         County_subdivision            a         Y     b             c  \
# 0      District 12, Iberia    44.918056  0.724463   0.0   1146.394372
# 1       District 1, Iberia     4.956944  0.977574   0.0    333.192221
# 2       District 6, Iberia     2.136389  1.169503   0.0    281.950643
# 3      District 13, Iberia     5.618889  0.516980   0.0    441.699060
# 4       District 3, Iberia    21.766944  2.152337   0.0    441.699060
# ..                     ...          ...       ...   ...           ...
# 161  District 7, St. James     1.528056  1.947249  18.0   2029.541769
# 162  District 5, St. James    12.034444  5.134487  18.0   2029.541769
# 163  District 2, St. James     1.315556  3.804776  18.0   3055.776876
# 164  District 4, St. James   173.765000  4.553310  18.0   2029.541769
# 165   New Orleans, Orleans  6154.445000  8.282089  11.0  17479.085550
#
#               d      e     f  sub            County  coun  Housings  \
# ...

# %%
merged5.corr()
# Out:
#                   a         Y         b         c         d         e  \
# a          1.000000  0.286220  0.123535  0.246923 -0.171846  0.017971
# Y          0.286220  1.000000  0.506071  0.460624 -0.134549  0.012029
# b          0.123535  0.506071  1.000000  0.482677 -0.682900  0.140952
# c          0.246923  0.460624  0.482677  1.000000 -0.298572  0.026947
# d         -0.171846 -0.134549 -0.682900 -0.298572  1.000000 -0.070749
# e          0.017971  0.012029  0.140952  0.026947 -0.070749  1.000000
# f          0.049119 -0.044972  0.007828 -0.072050 -0.195816 -0.498984
# sub        0.028122  0.161044  0.033810  0.065837 -0.122950  0.007738
# coun       0.039864  0.126939  0.190677  0.168515 -0.158343 -0.006965
# Housings   0.441177  0.117940 -0.019193  0.235144 -0.072854  0.019017
# House_age -0.141795 -0.188742  0.009296  0.119185 -0.198073 -0.372695
# Hispanic  -0.105525 -0.015652  0.006263  0.015378  0.026853 -0.152627
# ...

# %%
merged5.to_csv(r"C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\Data\merged dataset\data_trial.csv",index = False)

# %%
merged5.describe()
# Out:
#                   a           Y           b             c           d  \
# count    166.000000  166.000000  166.000000    166.000000  166.000000
# mean     490.071290    3.189836   12.487952   4051.813011   67.630501
# std     1202.943983    2.815119    9.133513   7045.784507   55.064340
# min        0.500000    0.100935    0.000000      0.000000    5.734607
# 25%        4.410347    1.038939    3.000000    661.649405   30.813516
# 50%       76.549028    2.278196   13.000000   1539.007201   49.067858
# 75%      451.278264    4.684079   18.000000   4001.726683   87.523734
# max    11441.321670   12.881592   29.000000  45117.710900  287.376899
#
#                    e           f         sub        coun       Housings  \
# count     166.000000  166.000000  166.000000  166.000000     166.000000
# mean    53791.481928   29.695181   82.500000   18.759036    6088.530120
# std     19837.677451   23.732734   48.064193    9.561400   15947.890415
# ...
