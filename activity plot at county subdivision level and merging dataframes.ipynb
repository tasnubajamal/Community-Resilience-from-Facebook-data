# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\Data\resilience\act_with_intersection.csv")

# %%
df.head()
# Out:
#    index  polygon_id polygon_name   level            date_time  n_baseline  \
# 0   1766     1106112  District 4B  LEVEL4  2021-08-25 16:00:00  144.145623
# 1   1769     1106112  District 4B  LEVEL4  2021-08-26 16:00:00  145.609977
# 2   1772     1106112  District 4B  LEVEL4  2021-08-27 16:00:00  133.833333
# 3   1775     1106112  District 4B  LEVEL4  2021-08-28 16:00:00  131.333333
# 4   1778     1106112  District 4B  LEVEL4  2021-08-29 16:00:00  139.250000
#
#    n_crisis  n_difference  percent_change  clipped_z_score  ...  \
# 0     135.0     -9.145623       -6.300998        -0.830042  ...
# 1     143.0     -2.609977       -1.780218        -0.266543  ...
# 2     114.0    -19.833333      -14.709518        -1.958852  ...
# 3     116.0    -15.333333      -11.586902        -1.441473  ...
# 4     132.0     -7.250000       -5.169340        -0.756519  ...
#
#                       Location    date_str numeric     Ratio  \
# 0  District 4B, East Feliciana  2021-08-25       0 -0.063010
# ...

# %%
df['date'] = pd.to_datetime(df['date'])
df2 = df.loc[(df['date'] <= "2021-09-30")]

# %%
df2['new_ratio'] = df2['Ratio'] +1
# Out:
# C:\Users\ta444503\AppData\Local\Temp/ipykernel_27124/587367238.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['new_ratio'] = df2['Ratio'] +1

# %%
df2.head()
# Out:
#    index  polygon_id polygon_name   level            date_time  n_baseline  \
# 0   1766     1106112  District 4B  LEVEL4  2021-08-25 16:00:00  144.145623
# 1   1769     1106112  District 4B  LEVEL4  2021-08-26 16:00:00  145.609977
# 2   1772     1106112  District 4B  LEVEL4  2021-08-27 16:00:00  133.833333
# 3   1775     1106112  District 4B  LEVEL4  2021-08-28 16:00:00  131.333333
# 4   1778     1106112  District 4B  LEVEL4  2021-08-29 16:00:00  139.250000
#
#    n_crisis  n_difference  percent_change  clipped_z_score  ...    date_str  \
# 0     135.0     -9.145623       -6.300998        -0.830042  ...  2021-08-25
# 1     143.0     -2.609977       -1.780218        -0.266543  ...  2021-08-26
# 2     114.0    -19.833333      -14.709518        -1.958852  ...  2021-08-27
# 3     116.0    -15.333333      -11.586902        -1.441473  ...  2021-08-28
# 4     132.0     -7.250000       -5.169340        -0.756519  ...  2021-08-29
#
# ...

# %%
df2['Location'].unique()
# Out:
# array(['District 4B, East Feliciana', 'District 3, St. John the Baptist',
#        'District 3, Washington', 'District 3, St. Martin',
#        'District 2, St. Tammany', 'District 2, Lafourche',
#        'District 2, Jefferson', 'District 8, Ascension',
#        'District 6, Terrebonne', 'District 6, Plaquemines',
#        'District F, Lafayette', 'District 7, Assumption',
#        'District 7, St. John the Baptist', 'District 7, East Baton Rouge',
#        'District 5, Tangipahoa', 'District 4, Lafourche',
#        'District 4, Plaquemines', 'District 4, Tangipahoa',
#        'District 4, Assumption', 'District 10, St. Tammany',
#        'District 10, Iberville', 'District E, St. Bernard',
#        'District C, St. Bernard', 'District 3, St. Tammany',
#        'District 2, St. Charles', 'District 2, St. Landry',
#        'District 8, St. Martin', 'District 8, Iberville',
#        'District B, St. Bernard', 'District 4, St. Charles',
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as md
import dateutil

# %%
bap3 = df2[df2['Location'] == 'District 3, St. John the Baptist']
Pl9 = df2[df2['Location'] == 'District 9, Plaquemines']
tam13 = df2[df2['Location'] == 'District 13, St. Tammany']
Ass5 = df2[df2['Location'] == 'District 5, Assumption']
terr2 = df2[df2['Location'] == 'District 2, Terrebonne']
liv5 = df2[df2['Location'] == 'District 5, Livingston']
Orleans = df2[df2['Location'] == 'New Orleans, Orleans']
eb9 = df2[df2['Location'] == 'District 9, East Baton Rouge']
tr8 = df2[df2['Location'] == 'District 8, Terrebonne']
tan2 = df2[df2['Location'] == 'District 2, Tangipahoa']
jeff2 = df2[df2['Location'] == 'District 2, Jefferson']
laf5 = df2[df2['Location'] == 'District 5, Lafourche']

# %%
x1 = [df2['date'].iloc[0],df2['date'].iloc[20]]
y1 = [0,0]

fig, ax = plt.subplots(figsize=(22, 10))
#plt_data = range(5,9)
plt.subplots_adjust(bottom=0.2)
plt.xticks( rotation=90 )
csfont = {'fontname':'Times New Roman'}
ax=plt.gca()
ax.set_xticks(df2['date'])

xfmt = md.DateFormatter('%Y-%m-%d')
ax.xaxis.set_major_formatter(xfmt)

plt.plot(bap3['date'],bap3['new_ratio'],'-o',label = 'District 3, St. John the Baptist')
plt.plot(Pl9['date'],Pl9['new_ratio'],'-o',label = 'District 9, Plaquemines')
plt.plot(tam13['date'],tam13['new_ratio'],'-o',label = 'District 13, St. Tammany')
plt.plot(Ass5['date'],Ass5['new_ratio'],'-o',label = 'District 5, Assumption')
plt.plot(terr2['date'],terr2['new_ratio'],'-o',label = 'District 2, Terrebonne')
plt.plot(liv5['date'],liv5['new_ratio'],'-o',label = 'District 5, Livingston')
plt.plot(Orleans['date'],Orleans['new_ratio'],'-o',label = 'New Orleans, Orleans')
plt.plot(eb9['date'],eb9['new_ratio'],'-o',label = 'District 9, East Baton Rouge')
plt.plot(tr8['date'],tr8['new_ratio'],'-o',label = 'District 8, Terrebonne')
plt.plot(tan2['date'],tan2['new_ratio'],'-o',label = 'District 2, Tangipahoa')
plt.plot(jeff2['date'],jeff2['new_ratio'],'-o',label = 'District 2, Jefferson')
plt.plot(laf5['date'],laf5['new_ratio'],'-o',label = 'District 5, Lafourche')


plt.plot(x1,y1,'--')

plt.xlabel("Date",size = 20, **csfont, labelpad = 40)
plt.ylabel("Activity", size = 20, **csfont, labelpad = 25)

plt.legend()

# %%
x1 = [df2['date'].iloc[0],df2['date'].iloc[20]]
y1 = [1,1]

fig, ax = plt.subplots(figsize=(22, 10))
#plt_data = range(5,9)
plt.subplots_adjust(bottom=0.2)
plt.xticks( rotation=90 )
csfont = {'fontname':'Times New Roman'}
ax=plt.gca()
ax.set_xticks(df2['date'])

xfmt = md.DateFormatter('%Y-%m-%d')
ax.xaxis.set_major_formatter(xfmt)

plt.plot(bap3['date'],bap3['new_ratio'],'-o',label = 'District 3, St. John the Baptist')
plt.plot(Pl9['date'],Pl9['new_ratio'],'-o',label = 'District 9, Plaquemines')
plt.plot(tam13['date'],tam13['new_ratio'],'-o',label = 'District 13, St. Tammany')
plt.plot(Ass5['date'],Ass5['new_ratio'],'-o',label = 'District 5, Assumption')
plt.plot(terr2['date'],terr2['new_ratio'],'-o',label = 'District 2, Terrebonne')
plt.plot(liv5['date'],liv5['new_ratio'],'-o',label = 'District 5, Livingston')
plt.plot(Orleans['date'],Orleans['new_ratio'],'-o',label = 'New Orleans, Orleans')
plt.plot(eb9['date'],eb9['new_ratio'],'-o',label = 'District 9, East Baton Rouge')
plt.plot(tr8['date'],tr8['new_ratio'],'-o',label = 'District 8, Terrebonne')
plt.plot(tan2['date'],tan2['new_ratio'],'-o',label = 'District 2, Tangipahoa')
plt.plot(jeff2['date'],jeff2['new_ratio'],'-o',label = 'District 2, Jefferson')
plt.plot(laf5['date'],laf5['new_ratio'],'-o',label = 'District 5, Lafourche')


plt.plot(x1,y1,'--')

plt.xlabel("Date",size = 20, **csfont, labelpad = 40)
plt.ylabel("Activity", size = 20, **csfont, labelpad = 25)

plt.legend()

# %%
x1 = [df2['date'].iloc[0],df2['date'].iloc[20]]
y1 = [1,1]

fig, ax = plt.subplots(figsize=(22, 15))
#plt_data = range(5,9)
plt.subplots_adjust(bottom=0.2)
plt.xticks( rotation=90 )
csfont = {'fontname':'Times New Roman'}
ax=plt.gca()
ax.set_xticks(df2['date'])

xfmt = md.DateFormatter('%Y-%m-%d')
ax.xaxis.set_major_formatter(xfmt)

plt.plot(bap3['date'],bap3['new_ratio'],'-o',label = 'District 3, St. John the Baptist')
plt.plot(Pl9['date'],Pl9['new_ratio'],'-o',label = 'District 9, Plaquemines')
plt.plot(tam13['date'],tam13['new_ratio'],'-o',label = 'District 13, St. Tammany')
plt.plot(Ass5['date'],Ass5['new_ratio'],'-o',label = 'District 5, Assumption')
plt.plot(terr2['date'],terr2['new_ratio'],'-o',label = 'District 2, Terrebonne')
plt.plot(liv5['date'],liv5['new_ratio'],'-o',label = 'District 5, Livingston')
plt.plot(Orleans['date'],Orleans['new_ratio'],'-o',label = 'New Orleans, Orleans')
plt.plot(eb9['date'],eb9['new_ratio'],'-o',label = 'District 9, East Baton Rouge')
plt.plot(tr8['date'],tr8['new_ratio'],'-o',label = 'District 8, Terrebonne')
plt.plot(tan2['date'],tan2['new_ratio'],'-o',label = 'District 2, Tangipahoa')
plt.plot(jeff2['date'],jeff2['new_ratio'],'-o',label = 'District 2, Jefferson')
plt.plot(laf5['date'],laf5['new_ratio'],'-o',label = 'District 5, Lafourche')


plt.plot(x1,y1,'--')

plt.xlabel("Date",size = 20, **csfont, labelpad = 40)
plt.ylabel("Activity", size = 20, **csfont, labelpad = 25)

plt.legend()
fig.savefig(r'C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\activity_cousb.png',dpi=600,bbox_inches='tight')

# %%
x1 = [df2['date'].iloc[0],df2['date'].iloc[30]]
y1 = [1,1]

fig, ax = plt.subplots(figsize=(22, 13))
#plt_data = range(5,9)
plt.subplots_adjust(bottom=0.2)
plt.xticks( rotation=90 )
csfont = {'fontname':'Times New Roman'}
ax=plt.gca()
ax.set_xticks(df2['date'])

xfmt = md.DateFormatter('%Y-%m-%d')
ax.xaxis.set_major_formatter(xfmt)

plt.plot(bap3['date'],bap3['new_ratio'],'-o',label = 'District 3, St. John the Baptist')
plt.plot(Pl9['date'],Pl9['new_ratio'],'-o',label = 'District 9, Plaquemines')
plt.plot(tam13['date'],tam13['new_ratio'],'-o',label = 'District 13, St. Tammany')
#plt.plot(Ass5['date'],Ass5['new_ratio'],'-o',label = 'District 5, Assumption')
plt.plot(terr2['date'],terr2['new_ratio'],'-o',label = 'District 2, Terrebonne')
plt.plot(liv5['date'],liv5['new_ratio'],'-o',label = 'District 5, Livingston')
plt.plot(Orleans['date'],Orleans['new_ratio'],'-o',label = 'New Orleans, Orleans')
plt.plot(eb9['date'],eb9['new_ratio'],'-o',label = 'District 9, East Baton Rouge')
plt.plot(tr8['date'],tr8['new_ratio'],'-o',label = 'District 8, Terrebonne')
plt.plot(tan2['date'],tan2['new_ratio'],'-o',label = 'District 2, Tangipahoa')
plt.plot(jeff2['date'],jeff2['new_ratio'],'-o',label = 'District 2, Jefferson')
plt.plot(laf5['date'],laf5['new_ratio'],'-o',label = 'District 5, Lafourche')


plt.plot(x1,y1,'--')

plt.xlabel("Date",size = 20, **csfont, labelpad = 40)
plt.ylabel("Activity", size = 20, **csfont, labelpad = 25)

plt.legend()
fig.savefig(r'C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\activity_cousb2.png',dpi=600,bbox_inches='tight')

# %%
x1 = [df2['date'].iloc[0],df2['date'].iloc[36]]
y1 = [1,1]

fig, ax = plt.subplots(figsize=(22, 13))
#plt_data = range(5,9)
plt.subplots_adjust(bottom=0.2)
plt.xticks( rotation=90 )
csfont = {'fontname':'Times New Roman'}
ax=plt.gca()
ax.set_xticks(df2['date'])

xfmt = md.DateFormatter('%Y-%m-%d')
ax.xaxis.set_major_formatter(xfmt)

plt.plot(jeff2['date'],jeff2['new_ratio'],'-o',label = 'District 2, Jefferson')

plt.plot(x1,y1,'--')

plt.xlabel("Date",size = 20, **csfont, labelpad = 40)
plt.ylabel("Activity", size = 20, **csfont, labelpad = 25)

plt.legend()
fig.savefig(r'C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\jeff_cousb.png',dpi=600,bbox_inches='tight')

# %%
fd = pd.read_csv(r"C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\Data\RITIS\outut from ritis data\duration_roadblockage_with_all_plaquemines.csv")

# %%
fd.describe()
# Out:
#        Loss_of_Resilience  Resilience  obstruction_time2  \
# count          166.000000  166.000000         166.000000
# mean            -3.189836   32.810164         490.008944
# std              2.815119    2.815119        1202.969534
# min            -12.881592   23.118408          -5.174722
# 25%             -4.684079   31.315921           4.327153
# 50%             -2.278196   33.721804          76.549028
# 75%             -1.038939   34.961061         451.278264
# max             -0.100935   35.899065       11441.321667
#
#        Abs_Loss_of_Resilience
# count              166.000000
# mean                 3.189836
# std                  2.815119
# min                  0.100935
# 25%                  1.038939
# 50%                  2.278196
# 75%                  4.684079
# max                 12.881592

# %%
res = pd.read_csv(r"C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\Data\resilience\resilience_166countysubdivision.csv")

# %%
pow = pd.read_csv(r"C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\Data\output from power data\power_with_resilience.csv")

# %%
rit = pd.read_csv(r"C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\Data\RITIS\outut from ritis data\duration_roadblockage_with_all_plaquemines.csv")

# %%
path = pd.read_csv(r"C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\Data\output from path data\hur_path_merges.csv")

# %%
fema = pd.read_csv(r"C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\Data\FEMA\outputfromfema\fema_county_subdivision.csv")

# %%
res.head()
# Out:
#                         County_subdivision  Loss_of_Resilience  Resilience
# 0       District 4B, East Feliciana Parish           -1.049961   34.950039
# 1  District 3, St. John the Baptist Parish           -4.727669   31.272331
# 2            District 3, Washington Parish           -0.394778   35.605222
# 3            District 3, St. Martin Parish           -2.390723   33.609277
# 4           District 2, St. Tammany Parish           -1.602185   34.397815

# %%
pow.head()
# Out:
#                         County_subdivision  Loss_of_Resilience  Resilience  \
# 0       District 4B, East Feliciana Parish           -1.049961   34.950039
# 1        District 3, East Feliciana Parish           -0.802235   35.197765
# 2        District 6, East Feliciana Parish           -1.458779   34.541221
# 3  District 3, St. John the Baptist Parish           -4.727669   31.272331
# 4  District 7, St. John the Baptist Parish           -8.626069   27.373931
#
#                  County  Restoration_time   abs_res
# 0        East Feliciana               7.0  1.049961
# 1        East Feliciana               7.0  0.802235
# 2        East Feliciana               7.0  1.458779
# 3  St. John the Baptist              27.0  4.727669
# 4  St. John the Baptist              27.0  8.626069

# %%
rit['Place'] = rit['Place'] + ' Parish'

# %%
rit.head()
# Out:
#                                      Place  Loss_of_Resilience  Resilience  \
# 0       District 4B, East Feliciana Parish           -1.049961   34.950039
# 1  District 3, St. John the Baptist Parish           -4.727669   31.272331
# 2            District 3, Washington Parish           -0.394778   35.605222
# 3            District 3, St. Martin Parish           -2.390723   33.609277
# 4           District 2, St. Tammany Parish           -1.602185   34.397815
#
#    obstruction_time2  Abs_Loss_of_Resilience
# 0          57.263333                1.049961
# 1          41.376111                4.727669
# 2           1.851667                0.394778
# 3           1.583611                2.390723
# 4         198.328611                1.602185

# %%
path.head()
# Out:
#    Distance_to_hurr_path          County_subdivision  Loss_of_Resilience  \
# 0             110.539537  District 12, Iberia Parish           -0.724463
# 1             118.671008   District 1, Iberia Parish           -0.977574
# 2             115.778635   District 6, Iberia Parish           -1.169503
# 3             129.132666  District 13, Iberia Parish           -0.516980
# 4             121.246905   District 3, Iberia Parish           -2.152337
#
#    Resilience  abs_loss_of_resilience
# 0   35.275537                0.724463
# 1   35.022426                0.977574
# 2   34.830497                1.169503
# 3   35.483020                0.516980
# 4   33.847663                2.152337

# %%
fema2.head()
# Out:
#    Loss_of_Resilience  Resilience                                    Place  \
# 0           -1.049961   34.950039       District 4B, East Feliciana Parish
# 1           -0.802235   35.197765        District 3, East Feliciana Parish
# 2           -1.458779   34.541221        District 6, East Feliciana Parish
# 3           -4.727669   31.272331  District 3, St. John the Baptist Parish
# 4           -8.626069   27.373931  District 7, St. John the Baptist Parish
#
#    averageFemaInspectedDamage_x  totalDamage
# 0                    968.414868    330229.47
# 1                   1164.636369         0.00
# 2                    872.277964    732713.49
# 3                   8018.730057         0.00
# 4                   8018.730057         0.00

# %%
fema2 =  fema[['Loss_of_Resilience','Resilience','Place','averageFemaInspectedDamage_x','totalDamage']]

# %%
fema2['Place'] = fema2['Place'] + ' Parish'
# Out:
# C:\Users\ta444503\AppData\Local\Temp/ipykernel_11056/2093102583.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fema2['Place'] = fema2['Place'] + ' Parish'

# %%
rit.rename(columns={'Place':'County_subdivision'}, inplace=True)
fema2.rename(columns={'Place':'County_subdivision'}, inplace=True)
# Out:
# C:\Users\ta444503\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
one = res.merge(rit, on = ['County_subdivision'])

# %%
one = one.drop(columns = ['Loss_of_Resilience_y','Resilience_y'])

# %%
res.shape
# Out:
# (166, 3)

# %%
two = one.merge(pow, on = ['County_subdivision'])

# %%
two = two.drop(columns=['Loss_of_Resilience_x','Resilience_x'])

# %%
two
# Out:
#                           County_subdivision  obstruction_time2  \
# 0         District 4B, East Feliciana Parish          57.263333
# 1    District 3, St. John the Baptist Parish          41.376111
# 2              District 3, Washington Parish           1.851667
# 3              District 3, St. Martin Parish           1.583611
# 4             District 2, St. Tammany Parish         198.328611
# ..                                       ...                ...
# 161  District 5, St. John the Baptist Parish        1524.126944
# 162           District 7, Plaquemines Parish           1.040833
# 163           District 8, Plaquemines Parish         300.000000
# 164           District 9, Plaquemines Parish         284.556944
# 165            District 4, Assumption Parish           3.095278
#
#      Abs_Loss_of_Resilience  Loss_of_Resilience  Resilience  \
# 0                  1.049961           -1.049961   34.950039
# 1                  4.727669           -4.727669   31.272331
# ...

# %%
three = two.merge(fema2, on = ['County_subdivision'])

# %%
three
# Out:
#                           County_subdivision  obstruction_time2  \
# 0         District 4B, East Feliciana Parish          57.263333
# 1    District 3, St. John the Baptist Parish          41.376111
# 2              District 3, Washington Parish           1.851667
# 3              District 3, St. Martin Parish           1.583611
# 4             District 2, St. Tammany Parish         198.328611
# ..                                       ...                ...
# 161  District 5, St. John the Baptist Parish        1524.126944
# 162           District 7, Plaquemines Parish           1.040833
# 163           District 8, Plaquemines Parish         300.000000
# 164           District 9, Plaquemines Parish         284.556944
# 165            District 4, Assumption Parish           3.095278
#
#      Abs_Loss_of_Resilience  Loss_of_Resilience_x  Resilience_x  \
# 0                  1.049961             -1.049961     34.950039
# 1                  4.727669             -4.727669     31.272331
# ...

# %%
three = three.drop(columns = ['Loss_of_Resilience_y','Resilience_y'])

# %%
three
# Out:
#                           County_subdivision  obstruction_time2  \
# 0         District 4B, East Feliciana Parish          57.263333
# 1    District 3, St. John the Baptist Parish          41.376111
# 2              District 3, Washington Parish           1.851667
# 3              District 3, St. Martin Parish           1.583611
# 4             District 2, St. Tammany Parish         198.328611
# ..                                       ...                ...
# 161  District 5, St. John the Baptist Parish        1524.126944
# 162           District 7, Plaquemines Parish           1.040833
# 163           District 8, Plaquemines Parish         300.000000
# 164           District 9, Plaquemines Parish         284.556944
# 165            District 4, Assumption Parish           3.095278
#
#      Abs_Loss_of_Resilience  Loss_of_Resilience_x  Resilience_x  \
# 0                  1.049961             -1.049961     34.950039
# 1                  4.727669             -4.727669     31.272331
# ...

# %%
four = three.merge(path, on = ['County_subdivision'])

# %%
four
# Out:
#                           County_subdivision  obstruction_time2  \
# 0         District 4B, East Feliciana Parish          57.263333
# 1    District 3, St. John the Baptist Parish          41.376111
# 2              District 3, Washington Parish           1.851667
# 3              District 3, St. Martin Parish           1.583611
# 4             District 2, St. Tammany Parish         198.328611
# ..                                       ...                ...
# 161  District 5, St. John the Baptist Parish        1524.126944
# 162           District 7, Plaquemines Parish           1.040833
# 163           District 8, Plaquemines Parish         300.000000
# 164           District 9, Plaquemines Parish         284.556944
# 165            District 4, Assumption Parish           3.095278
#
#      Abs_Loss_of_Resilience  Loss_of_Resilience_x  Resilience_x  \
# 0                  1.049961             -1.049961     34.950039
# 1                  4.727669             -4.727669     31.272331
# ...

# %%
five = four[['County_subdivision','obstruction_time2','Abs_Loss_of_Resilience','Restoration_time','Resilience','averageFemaInspectedDamage_x','Distance_to_hurr_path']]

# %%
five['obstruction_time2'] = five['obstruction_time2'].abs()
# Out:
# C:\Users\ta444503\AppData\Local\Temp/ipykernel_11056/3628172279.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   five['obstruction_time2'] = five['obstruction_time2'].abs()

# %%
five.corr()
# Out:
#                               obstruction_time2  Abs_Loss_of_Resilience  \
# obstruction_time2                      1.000000                0.286220
# Abs_Loss_of_Resilience                 0.286220                1.000000
# Restoration_time                       0.123535                0.506071
# Resilience                            -0.286220               -1.000000
# averageFemaInspectedDamage_x           0.246923                0.460624
# Distance_to_hurr_path                 -0.171846               -0.134549
#
#                               Restoration_time  Resilience  \
# obstruction_time2                     0.123535   -0.286220
# Abs_Loss_of_Resilience                0.506071   -1.000000
# Restoration_time                      1.000000   -0.506071
# Resilience                           -0.506071    1.000000
# averageFemaInspectedDamage_x          0.482677   -0.460624
# Distance_to_hurr_path                -0.682900    0.134549
#
# ...

# %%
#five.to_csv(r"C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\Data\merged dataset\merged_without_demographic.csv",index = False)

# %%
five.rename(columns={'obstruction_time2':'Duration of Road Blockage'}, inplace=True)
five.rename(columns={'Abs_Loss_of_Resilience':'Loss of Resilience'}, inplace=True)
five.rename(columns={'Restoration_time':'Restoration Time for Power Outage'}, inplace=True)
five.rename(columns={'averageFemaInspectedDamage_x':'Property Damage'}, inplace=True)
five.rename(columns={'Distance_to_hurr_path':'Shortest Distance from County Subdivision Center to Hurricane Path'}, inplace=True)
# Out:
# C:\Users\ta444503\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
five.rename(columns={'Shortest Distance from County Subdivision Center to Hurricane Path':'Distance to Hurricane Path'}, inplace=True)

# %%
five.corr()
# Out:
#                                    Duration of Road Blockage  \
# Duration of Road Blockage                           1.000000
# Loss of Resilience                                  0.286220
# Restoration Time for Power Outage                   0.123535
# Resilience                                         -0.286220
# Property Damage                                     0.246923
# Distance to Hurricane Path                         -0.171846
#
#                                    Loss of Resilience  \
# Duration of Road Blockage                    0.286220
# Loss of Resilience                           1.000000
# Restoration Time for Power Outage            0.506071
# Resilience                                  -1.000000
# Property Damage                              0.460624
# Distance to Hurricane Path                  -0.134549
#
#                                    Restoration Time for Power Outage  \
# Duration of Road Blockage                                   0.123535
# ...

# %%
five = five.drop(columns = ['Resilience'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

cor = five.corr()
#plt.subplots(figsize=(8,8))
plt.figure(figsize=(8,8))
sns.heatmap(cor, annot=True, cmap="YlGnBu")
plt.show()

# %%
import pandas as pd
from sklearn import linear_model
import statsmodels.api as sm

# %%
X = five.drop(columns = ['Loss of Resilience']) # here we have 2 variables for multiple regression. If you just want to use one variable for simple linear regression, then use X = df['Interest_Rate'] for example.Alternatively, you may add additional variables within the brackets
Y = five['Loss of Resilience']
 
# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X, Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)

# prediction with sklearn
#New_Interest_Rate = 2.75
#New_Unemployment_Rate = 5.3
#print ('Predicted Stock Index Price: \n', regr.predict([[New_Interest_Rate ,New_Unemployment_Rate]]))

# with statsmodels
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(Y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
# Intercept:
#  -1.4149667102820418
# Coefficients:
#  [5.25365835e-04 2.04566797e-01 8.40045107e-05 2.14747008e-02]
#                             OLS Regression Results
# ...
# Dep. Variable:     Loss of Resilience   R-squared:                       0.440
# Model:                            OLS   Adj. R-squared:                  0.427
# Method:                 Least Squares   F-statistic:                     31.68
# Date:                Sat, 11 Jun 2022   Prob (F-statistic):           1.83e-19
# Time:                        14:38:48   Log-Likelihood:                -358.66
# No. Observations:                 166   AIC:                             727.3
# Df Residuals:                     161   BIC:                             742.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
X = five.drop(columns = ['Restoration Time for Power Outage','Loss of Resilience','Property Damage','Duration of Road Blockage']) # here we have 2 variables for multiple regression. If you just want to use one variable for simple linear regression, then use X = df['Interest_Rate'] for example.Alternatively, you may add additional variables within the brackets
Y = five['Loss of Resilience']
 
# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X, Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)

# prediction with sklearn
#New_Interest_Rate = 2.75
#New_Unemployment_Rate = 5.3
#print ('Predicted Stock Index Price: \n', regr.predict([[New_Interest_Rate ,New_Unemployment_Rate]]))

# with statsmodels
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(Y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
# Intercept:
#  3.655045919655233
# Coefficients:
#  [-0.00687871]
#                             OLS Regression Results
# ...
# Dep. Variable:     Loss of Resilience   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     3.024
# Date:                Sat, 11 Jun 2022   Prob (F-statistic):             0.0839
# Time:                        21:06:58   Log-Likelihood:                -405.34
# No. Observations:                 166   AIC:                             814.7
# Df Residuals:                     164   BIC:                             820.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
X = five.drop(columns = ['Restoration Time for Power Outage','Loss of Resilience','Distance to Hurricane Path']) # here we have 2 variables for multiple regression. If you just want to use one variable for simple linear regression, then use X = df['Interest_Rate'] for example.Alternatively, you may add additional variables within the brackets
Y = five['Loss of Resilience']
 
# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X, Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)

# prediction with sklearn
#New_Interest_Rate = 2.75
#New_Unemployment_Rate = 5.3
#print ('Predicted Stock Index Price: \n', regr.predict([[New_Interest_Rate ,New_Unemployment_Rate]]))

# with statsmodels
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(Y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
# Intercept:
#  2.3069055249274673
# Coefficients:
#  [0.00042985 0.00016592]
#                             OLS Regression Results
# ...
# Dep. Variable:     Loss of Resilience   R-squared:                       0.244
# Model:                            OLS   Adj. R-squared:                  0.235
# Method:                 Least Squares   F-statistic:                     26.28
# Date:                Sat, 11 Jun 2022   Prob (F-statistic):           1.28e-10
# Time:                        20:59:21   Log-Likelihood:                -383.65
# No. Observations:                 166   AIC:                             773.3
# Df Residuals:                     163   BIC:                             782.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# ...

# %%
df = pd.read_csv(r"C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\Data\ACS\county_subdivision\DP_03.csv", low_memory=False)

# %%
income = df[['NAME','DP03_0062E','DP03_0063E']]

# %%
income.head()
# Out:
#                                        NAME  DP03_0062E  DP03_0063E
# 0      District 8, Vernon Parish, Louisiana       42460       57018
# 1     District 10, Vernon Parish, Louisiana       30083       54746
# 2     District 11, Vernon Parish, Louisiana       39896       46388
# 3     District 12, Vernon Parish, Louisiana       49435       64720
# 4  District 1, Washington Parish, Louisiana       36728       45740

# %%
income.shape
# Out:
# (576, 3)

# %%
income['NAME'] = income['NAME'].str.replace(', Louisiana', '')
# Out:
# C:\Users\ta444503\AppData\Local\Temp/ipykernel_11056/1827192241.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   income['NAME'] = income['NAME'].str.replace(', Louisiana', '')

# %%
income['NAME'] = income['NAME'].str.rstrip()
# Out:
# C:\Users\ta444503\AppData\Local\Temp/ipykernel_11056/1296304120.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   income['NAME'] = income['NAME'].str.rstrip()

# %%
income.rename(columns={'NAME':'County_subdivision'}, inplace=True)
income.rename(columns={'DP03_0062E':'Median Household Income'}, inplace=True)
income.rename(columns={'DP03_0063E':'Mean Household Income'}, inplace=True)
# Out:
# C:\Users\ta444503\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
income.head(2)
# Out:
#            County_subdivision  Median Household Income  Mean Household Income
# 0   District 8, Vernon Parish                    42460                  57018
# 1  District 10, Vernon Parish                    30083                  54746

# %%
income.loc[income['County_subdivision'] == 'New Orleans city, Orleans Parish', 'County_subdivision'] = 'New Orleans, Orleans Parish'
# Out:
# C:\Users\ta444503\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
six = five.merge(income,  on = ['County_subdivision'])

# %%
six.shape
# Out:
# (166, 8)

# %%
pd.set_option('display.max_rows', None)

# %%
six.corr()
# Out:
#                                    Duration of Road Blockage  \
# Duration of Road Blockage                           1.000000
# Loss of Resilience                                  0.286220
# Restoration Time for Power Outage                   0.123535
# Property Damage                                     0.246923
# Distance to Hurricane Path                         -0.171846
# Median Household Income                             0.031786
# Mean Household Income                               0.071948
#
#                                    Loss of Resilience  \
# Duration of Road Blockage                    0.286220
# Loss of Resilience                           1.000000
# Restoration Time for Power Outage            0.506071
# Property Damage                              0.460624
# Distance to Hurricane Path                  -0.134549
# Median Household Income                     -0.027316
# Mean Household Income                       -0.020393
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

cor = six.corr()
#plt.subplots(figsize=(8,8))
plt.figure(figsize=(8,8))
sns.heatmap(cor, annot=True, cmap="YlGnBu")
plt.show()

# %%
df = pd.read_csv(r"C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\Data\ACS\county_subdivision\DP_05.csv", low_memory=False)

# %%
black = df[['NAME','DP05_0078PE','DP05_0071PE']]

# %%
black.head()
# Out:
#                                        NAME  DP05_0078PE  DP05_0071PE
# 0      District 8, Vernon Parish, Louisiana         26.4          7.2
# 1     District 10, Vernon Parish, Louisiana         48.7          2.1
# 2     District 11, Vernon Parish, Louisiana         23.2         13.7
# 3     District 12, Vernon Parish, Louisiana          8.6          6.8
# 4  District 1, Washington Parish, Louisiana         28.7          3.9

# %%
black['NAME'] = black['NAME'].str.replace(', Louisiana', '')
black['NAME'] = black['NAME'].str.rstrip()
# Out:
# C:\Users\ta444503\AppData\Local\Temp/ipykernel_11056/3124871504.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   black['NAME'] = black['NAME'].str.replace(', Louisiana', '')
# C:\Users\ta444503\AppData\Local\Temp/ipykernel_11056/3124871504.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   black['NAME'] = black['NAME'].str.rstrip()

# %%
black.rename(columns={'NAME':'County_subdivision'}, inplace=True)
black.rename(columns={'DP05_0078PE':'% of Black population'}, inplace=True)
black.rename(columns={'DP05_0071PE':'% of Hispanic population'}, inplace=True)
#income.rename(columns={'DP03_0063E':'Mean Household Income'}, inplace=True)
# Out:
# C:\Users\ta444503\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
black.loc[black['County_subdivision'] == 'New Orleans city, Orleans Parish', 'County_subdivision'] = 'New Orleans, Orleans Parish'
# Out:
# C:\Users\ta444503\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
seven = six.merge(black,  on = ['County_subdivision'])

# %%
seven = seven.drop(columns= ['Mean Household Income'])
print(seven.shape)
# Out:
# (166, 9)

# %%
black
# Out:
#                           County_subdivision  % of Black population  \
# 0                  District 8, Vernon Parish                   26.4
# 1                 District 10, Vernon Parish                   48.7
# 2                 District 11, Vernon Parish                   23.2
# 3                 District 12, Vernon Parish                    8.6
# 4              District 1, Washington Parish                   28.7
# 5              District 2, Washington Parish                    8.0
# 6              District 3, Washington Parish                   38.7
# 7              District 4, Washington Parish                   55.7
# 8              District 5, Washington Parish                   12.6
# 9              District 6, Washington Parish                   48.1
# 10             District 7, Washington Parish                   21.0
# 11                District 1, Webster Parish                   13.0
# 12                District 2, Webster Parish                   83.9
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

cor = seven.corr()
#plt.subplots(figsize=(10,10))
plt.figure(figsize=(11,11))
sns.heatmap(cor, annot=True, cmap="YlGnBu")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

cor = seven.corr()
#plt.subplots(figsize=(10,10))
plt.figure(figsize=(11,11))
sns.heatmap(cor, annot=True, cmap="coolwarm")
plt.show()

# %%
df2.head()
# Out:
#               County_subdivision  Total housing  House built in 2014 or later  \
# 0      District 8, Vernon Parish           2255                           2.4
# 1     District 10, Vernon Parish            726                           1.0
# 2     District 11, Vernon Parish           3222                           1.2
# 3     District 12, Vernon Parish           1622                           0.4
# 4  District 1, Washington Parish           3189                           1.7
#
#    House within 2010 to 2013  House within 2000 to 2009  New house percentage  \
# 0                        6.7                        9.5                  18.6
# 1                       14.0                        9.8                  24.8
# 2                        7.5                       12.1                  20.8
# 3                        4.4                       21.0                  25.8
# 4                        1.7                       12.5                  15.9
#
# ...

# %%
X = seven.drop(columns = ['Loss of Resilience','County_subdivision']) # here we have 2 variables for multiple regression. If you just want to use one variable for simple linear regression, then use X = df['Interest_Rate'] for example.Alternatively, you may add additional variables within the brackets
Y = seven['Loss of Resilience']
 
# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X, Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)

# prediction with sklearn
#New_Interest_Rate = 2.75
#New_Unemployment_Rate = 5.3
#print ('Predicted Stock Index Price: \n', regr.predict([[New_Interest_Rate ,New_Unemployment_Rate]]))

# with statsmodels
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(Y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
# Intercept:
#  -1.6132687963916625
# Coefficients:
#  [ 5.21654329e-04  2.06260816e-01  8.55884825e-05  2.18151715e-02
#  -1.58318902e-09  4.82396235e-03]
#                             OLS Regression Results
# ...
# Dep. Variable:     Loss of Resilience   R-squared:                       0.443
# Model:                            OLS   Adj. R-squared:                  0.422
# Method:                 Least Squares   F-statistic:                     21.05
# Date:                Sat, 11 Jun 2022   Prob (F-statistic):           4.33e-18
# Time:                        22:07:59   Log-Likelihood:                -358.33
# No. Observations:                 166   AIC:                             730.7
# Df Residuals:                     159   BIC:                             752.4
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
seven.columns
# Out:
# Index(['County_subdivision', 'Duration of Road Blockage', 'Loss of Resilience',
#        'Restoration Time for Power Outage', 'Property Damage',
#        'Distance to Hurricane Path', 'Median Household Income',
#        '% of Black population'],
#       dtype='object')

# %%
seven.rename(columns={'Loss of Resilience':'Y'}, inplace=True)
seven.rename(columns={'Property Damage':'c'}, inplace=True)
seven.rename(columns={'Duration of Road Blockage':'a'}, inplace=True)
seven.rename(columns={'Distance to Hurricane Path':'d'}, inplace=True)
seven.rename(columns={'Restoration Time for Power Outage': 'b'}, inplace=True)
#seven.rename(columns={'Distance to Hurricane Path':'a'}, inplace=True)

# %%
seven.rename(columns={'Median Household Income':'e'}, inplace=True)
seven.rename(columns={'% of Black population': 'f'}, inplace=True)

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
# Encode labels in columns. 
seven['sub']= label_encoder.fit_transform(seven['County_subdivision'])

# %%
seven.Y.plot.density(color='green')
plt.title('Density plot for Resilience')
plt.show()

# %%
seven.Y.plot.kde(color='green')
plt.title('KDE-Density plot for Resilience')
plt.show()

# %%
plt.hist(seven['Y'])
# Out:
# (array([54., 41., 19., 18., 12.,  7.,  7.,  3.,  2.,  3.]),
#  array([ 0.10093492,  1.37900059,  2.65706626,  3.93513193,  5.2131976 ,
#          6.49126327,  7.76932894,  9.04739461, 10.32546028, 11.60352595,
#         12.88159162]),
#  <BarContainer object of 10 artists>)

# %%
seven.to_csv(r"C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\Data\merged dataset\data_for_R.csv",index=False)

# %%
seven['County'] = seven['County_subdivision'].str.rsplit(',').str[-1] 
seven['County'] = seven['County'].str.lstrip()
seven['County'] = seven['County'].str.rstrip()

seven['coun']= label_encoder.fit_transform(seven['County'])

# %%
seven.to_csv(r"C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\Data\merged dataset\data_for_R2.csv",index=False)

# %% [markdown]
# # merge hispanic data and housing data with previous dataset

# %%
df2 = pd.read_csv(r"C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\Data\ACS\county_subdivision\DP_04.csv", low_memory=False)
df2 = df2[['NAME','DP04_0001E','DP04_0017PE','DP04_0018PE','DP04_0019PE']]

# %%
df2['NAME'] = df2['NAME'].str.replace(', Louisiana', '')
df2['NAME'] = df2['NAME'].str.rstrip()
df2.rename(columns={'NAME': 'County_subdivision'}, inplace=True)
#without_duplicates_h['County'] = without_duplicates_h['County'].str.strip()
df2.rename(columns={'DP04_0001E': 'Total housing'}, inplace=True)
df2.rename(columns={'DP04_0017PE': 'House built in 2014 or later'}, inplace=True)
df2.rename(columns={'DP04_0018PE': 'House within 2010 to 2013'}, inplace=True)
df2.rename(columns={'DP04_0019PE': 'House within 2000 to 2009'}, inplace=True)

# %%
df2['New house percentage']= df2['House built in 2014 or later']+ df2['House within 2010 to 2013']+ df2['House within 2000 to 2009']

# %%
df2['% of houses age more than 21 years']=100 - df2['New house percentage']

# %%
datafrm = pd.read_csv(r"C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\Data\merged dataset\data_for_R2.csv")

# %%
datafrm.head()
# Out:
#                         County_subdivision           a         Y     b  \
# 0       District 4B, East Feliciana Parish   57.263333  1.049961   7.0
# 1  District 3, St. John the Baptist Parish   41.376111  4.727669  27.0
# 2            District 3, Washington Parish    1.851667  0.394778   8.0
# 3            District 3, St. Martin Parish    1.583611  2.390723   0.5
# 4           District 2, St. Tammany Parish  198.328611  1.602185  10.0
#
#              c           d      e     f  sub                       County  \
# 0   968.414868   44.872770  60334  37.8   86        East Feliciana Parish
# 1  8018.730057   20.702713  43784  75.2   63  St. John the Baptist Parish
# 2  1027.190517   91.944819  34809  38.7   70            Washington Parish
# 3   256.780718  109.054537  31116  49.8   65            St. Martin Parish
# 4  3136.539620   70.906177  65436   1.9   46           St. Tammany Parish
#
#    coun
# 0     8
# 1    25
# 2    34
# 3    27
# 4    29

# %%
df2 = df2[['County_subdivision','Total housing','% of houses age more than 21 years']]

# %%
df2.loc[df2['County_subdivision'] == 'New Orleans city, Orleans Parish', 'County_subdivision'] = 'New Orleans, Orleans Parish'

# %%
with_demo = datafrm.merge(df2,  on = ['County_subdivision'])

# %%
with_demo.shape
# Out:
# (166, 13)

# %% [markdown]
# # Could not collect land area

# %%
with_demo.head()
# Out:
#                         County_subdivision           a         Y     b  \
# 0       District 4B, East Feliciana Parish   57.263333  1.049961   7.0
# 1  District 3, St. John the Baptist Parish   41.376111  4.727669  27.0
# 2            District 3, Washington Parish    1.851667  0.394778   8.0
# 3            District 3, St. Martin Parish    1.583611  2.390723   0.5
# 4           District 2, St. Tammany Parish  198.328611  1.602185  10.0
#
#              c           d      e     f  sub                       County  \
# 0   968.414868   44.872770  60334  37.8   86        East Feliciana Parish
# 1  8018.730057   20.702713  43784  75.2   63  St. John the Baptist Parish
# 2  1027.190517   91.944819  34809  38.7   70            Washington Parish
# 3   256.780718  109.054537  31116  49.8   65            St. Martin Parish
# 4  3136.539620   70.906177  65436   1.9   46           St. Tammany Parish
#
#    coun  Total housing  % of houses age more than 21 years
# ...

# %%
with_demo['County'].unique()
# Out:
# array(['East Feliciana Parish', 'St. John the Baptist Parish',
#        'Washington Parish', 'St. Martin Parish', 'St. Tammany Parish',
#        'Lafourche Parish', 'Jefferson Parish', 'Ascension Parish',
#        'Terrebonne Parish', 'Plaquemines Parish', 'Lafayette Parish',
#        'Assumption Parish', 'East Baton Rouge Parish',
#        'Tangipahoa Parish', 'Iberville Parish', 'St. Bernard Parish',
#        'St. Charles Parish', 'St. Landry Parish', 'St. James Parish',
#        'St. Mary Parish', 'Orleans Parish', 'Cameron Parish',
#        'Iberia Parish', 'Vermilion Parish', 'Evangeline Parish',
#        'Livingston Parish', 'Jefferson Davis Parish', 'St. Helena Parish',
#        'Pointe Coupee Parish', 'Vernon Parish', 'West Baton Rouge Parish',
#        'Catahoula Parish', 'Allen Parish', 'Calcasieu Parish',
#        'Sabine Parish', 'Acadia Parish'], dtype=object)

# %% [markdown]
# # fema CERT data

# %% [markdown]
# ### did not find enough data

# %%
import seaborn as sns
import matplotlib.pyplot as plt

cor = with_demo.corr()
#plt.subplots(figsize=(10,10))
plt.figure(figsize=(13,13))
sns.heatmap(cor, annot=True, cmap="coolwarm")
plt.show()

# %%
with_demo.rename(columns={'Total housing':'Housings'}, inplace=True)
with_demo.rename(columns={'% of houses age more than 21 years':'House_age'}, inplace=True)

# %%
Hispanic = black['% of Hispanic population']

with_demo['Hispanic'] = Hispanic

# %%
import seaborn as sns
import matplotlib.pyplot as plt

cor = with_demo.corr()
#plt.subplots(figsize=(10,10))
plt.figure(figsize=(13,13))
sns.heatmap(cor, annot=True, cmap="coolwarm")
plt.show()

# %%
with_demo.to_csv(r"C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\Data\merged dataset\data_for_R3.csv",index=False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as plticker
from matplotlib.ticker import MaxNLocator

csfont = {'fontname':'Times New Roman'}

# %%
fig, ax = plt.subplots(figsize=(8, 6))
plt.hist(with_demo['Y'], bins =9, edgecolor = "black", align='mid')
plt.xlabel("Transient loss of resilience", size = 12,**csfont)
plt.ylabel("Number of county subdivisions", size = 12, **csfont)
#plt.title("Distribution of restoration time for power outage", fontsize = 11,**csfont)
plt.xticks(fontname = "Times New Roman")
plt.yticks(fontname = "Times New Roman")
#ax = plt.figure().gca()
ax.yaxis.set_major_locator(MaxNLocator(integer=True))

#plt.xticks(range(11))
#plt.grid()
#a_plot.set(ylim=(0, 20))
#plt.ticklabel_format(style='int', axis='y')
#plt.subplots_adjust(top=0.8)
plt.savefig("Histogram.png",dpi=600,bbox_inches='tight')

# %%
with_demo.rename(columns={'a':'Duration of road blockage'}, inplace=True)
with_demo.rename(columns={'b':'Restoration time for power outage'}, inplace=True)
with_demo.rename(columns={'c':'Property damage'}, inplace=True)
with_demo.rename(columns={'d':'Dist. to Hurricane Path'}, inplace=True)
with_demo.rename(columns={'e':'Income'}, inplace=True)
with_demo.rename(columns={'f':'Black'}, inplace=True)
with_demo.rename(columns={'Y':'Transient loss of resilience'}, inplace=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

with_demo2 = with_demo.drop(columns = ['sub','coun', 'Housings'])
cor = with_demo2.corr()
#plt.subplots(figsize=(10,10))
plt.figure(figsize=(13,13))
sns.heatmap(cor,annot=True,cmap="coolwarm")
plt.show()

# %%
cor = with_demo2.corr()
#plt.subplots(figsize=(10,10))
plt.figure(figsize=(13,13))
sns.heatmap(cor, annot=True, cmap="coolwarm")
plt.show()

plt.savefig(r'C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\Code\output\correlation.png')

# %%
x = with_demo2.describe()

# %%
x.transpose()
# Out:
#                                    count          mean           std  \
# Duration of road blockage          166.0  4.900713e+02  1.202944e+03
# Transient loss of resilience       166.0  3.189836e+00  2.815119e+00
# Restoration time for power outage  166.0  1.248795e+01  9.133513e+00
# Property damage                    166.0  4.051813e+03  7.045785e+03
# Dist. to Hurricane Path            166.0  6.763050e+01  5.506434e+01
# Income                             166.0 -3.962616e+06  5.174755e+07
# Black                              166.0  2.969518e+01  2.373273e+01
# House_age                          166.0  7.252289e+01  1.795912e+01
# Hispanic                           166.0  3.912651e+00  3.737495e+00
#
#                                             min           25%           50%  \
# Duration of road blockage          5.000000e-01      4.410347     76.549028
# Transient loss of resilience       1.009349e-01      1.038939      2.278196
# ...

# %% [markdown]
# # replacing negative income with county median income manually in the csv fileDataforR3

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\Data\merged dataset\data_for_R3.csv")

# %%
df.rename(columns={'a':'Duration of road blockage'}, inplace=True)
df.rename(columns={'b':'Restoration time for power outage'}, inplace=True)
df.rename(columns={'c':'Property damage'}, inplace=True)
df.rename(columns={'d':'Dist. to Hurricane Path'}, inplace=True)
df.rename(columns={'e':'Income'}, inplace=True)
df.rename(columns={'f':'Black'}, inplace=True)
df.rename(columns={'Y':'Transient loss of resilience'}, inplace=True)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
  
# the independent variables set
X = df[['Duration of road blockage', 'Restoration time for power outage', 'Property damage',
         'Dist. to Hurricane Path','Income','Black','Hispanic','House_age']]
  
# VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
  
# calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]

# %%
vif_data
# Out:
#                              feature        VIF
# 0          Duration of road blockage   1.285312
# 1  Restoration time for power outage   5.437969
# 2                    Property damage   1.926590
# 3            Dist. to Hurricane Path   3.419659
# 4                             Income   7.228967
# 5                              Black   3.553098
# 6                           Hispanic   2.186719
# 7                          House_age  11.886815

# %%
x = df.nlargest(n=25, columns=['Transient loss of resilience'])

# %%
y = x[['County_subdivision','Transient loss of resilience']]

# %%
y
# Out:
#                           County_subdivision  Transient loss of resilience
# 163           District 8, Plaquemines Parish                     12.881592
# 164           District 9, Plaquemines Parish                     12.221388
# 162           District 7, Plaquemines Parish                     11.616542
# 161  District 5, St. John the Baptist Parish                     11.070667
# 50             District 7, Terrebonne Parish                     10.944987
# 91              District 9, Lafourche Parish                     10.065399
# 149            District 1, Terrebonne Parish                      9.723650
# 9             District 6, Plaquemines Parish                      9.606036
# 39            District 3, St. Charles Parish                      8.715419
# 12   District 7, St. John the Baptist Parish                      8.626069
# 80             District 8, Terrebonne Parish                      8.567745
# ...

# %%
x2 = df.nsmallest(n=20, columns=['Transient loss of resilience'])
y2 = x2[['County_subdivision','Transient loss of resilience']]

# %%
y2
# Out:
#                        County_subdivision  Transient loss of resilience
# 48    District 4, East Baton Rouge Parish                      0.100935
# 123   District 3, East Baton Rouge Parish                      0.150738
# 139         District 13, Vermilion Parish                      0.257008
# 7            District 8, Ascension Parish                      0.294148
# 51   District 12, East Baton Rouge Parish                      0.295083
# 138         District 13, Iberville Parish                      0.298921
# 19          District 10, Iberville Parish                      0.304327
# 113         District 3, Livingston Parish                      0.335615
# 120             District 5, Iberia Parish                      0.338385
# 29          District 10, Ascension Parish                      0.356593
# 78         District 8, St. Tammany Parish                      0.364380
# 2           District 3, Washington Parish                      0.394778
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
dff = df.drop(columns = ['sub','coun', 'Housings'])
cor = dff.corr()
#plt.subplots(figsize=(10,10))
plt.figure(figsize=(11,11))
sns.heatmap(cor,annot=True,cmap="coolwarm")
plt.show()

# %%
x = dff.describe()
x.transpose()
# Out:
#                                    count          mean           std  \
# Duration of road blockage          166.0    490.071290   1202.943983
# Transient loss of resilience       166.0      3.189836      2.815119
# Restoration time for power outage  166.0     12.487952      9.133513
# Property damage                    166.0   4051.813011   7045.784507
# Dist. to Hurricane Path            166.0     67.630501     55.064340
# Income                             166.0  53791.481928  19837.677451
# Black                              166.0     29.695181     23.732734
# House_age                          166.0     72.522892     17.959117
# Hispanic                           166.0      3.912651      3.737495
#
#                                             min           25%           50%  \
# Duration of road blockage              0.500000      4.410347     76.549028
# Transient loss of resilience           0.100935      1.038939      2.278196
# ...

# %%
fema_remove_zero = df[df['c'] != 0]

# %%
fema_remove_zero.shape
# Out:
# (146, 14)

# %%
cor2 = fema_remove_zero.corr()
#plt.subplots(figsize=(10,10))
plt.figure(figsize=(11,11))
sns.heatmap(cor2,annot=True,cmap="coolwarm")
plt.show()

# %%
fema_remove_zero.to_csv(r'C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\Data\merged dataset\fema_remove_zero.csv',index=False)

# %%
fema_remove_zero.describe().transpose()
# Out:
#            count          mean           std           min           25%  \
# a          146.0    550.622532   1270.727139      0.500000      6.966389
# Y          146.0      3.270536      2.887190      0.100935      1.054496
# b          146.0     14.174658      8.434656      0.000000      8.250000
# c          146.0   4606.855889   7342.735427    107.960051    950.576978
# d          146.0     51.272806     28.546302      5.734607     29.469882
# e          146.0  54524.184932  18969.883835  16765.000000  40197.250000
# f          146.0     30.912329     23.277797      0.000000     11.725000
# sub        146.0     83.452055     47.076326      1.000000     42.500000
# coun       146.0     19.506849      9.141226      2.000000     11.500000
# Housings   146.0   6552.890411  16911.640730    500.000000   1447.250000
# House_age  146.0     73.330822     16.292323      7.500000     64.700000
# Hispanic   146.0      3.884932      3.788319      0.000000      0.800000
#
# ...

# %% [markdown]
# # DP03

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\Data\ACS\county_subdivision\DP_03.csv", low_memory=False)
eco = df[['NAME','DP03_0002PE','DP03_0025E','DP03_0136PE']]

# %%
import seaborn as sns
cor2 = eco.corr()
#plt.subplots(figsize=(10,10))
plt.figure(figsize=(11,11))
sns.heatmap(cor2,annot=True,cmap="coolwarm")
plt.show()

# %%
eco.describe().transpose()
# Out:
#              count          mean           std          min    25%   50%  \
# DP03_0002PE  576.0  5.421389e+01  1.036868e+01          3.6  48.40  55.8
# DP03_0025E   576.0 -8.680528e+06  9.284487e+07 -999999999.0  21.75  26.7
# DP03_0136PE  576.0  1.919271e+01  1.389547e+01          0.0   9.20  15.5
#
#                 75%   max
# DP03_0002PE  61.425  81.8
# DP03_0025E   31.600  63.6
# DP03_0136PE  26.500  87.7

# %%
import pandas as pd
df_02 = pd.read_csv(r"C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\Data\ACS\county_subdivision\DP_02.csv", low_memory=False)
dis = df_02[['NAME','DP02_0068PE','DP02_0072PE','DP02_0154PE']]

# %%
import seaborn as sns
cor2 = dis.corr()
#plt.subplots(figsize=(10,10))
plt.figure(figsize=(11,11))
sns.heatmap(cor2,annot=True,cmap="coolwarm")
plt.show()

# %%
dis.describe().transpose()
# Out:
#              count       mean        std   min     25%    50%     75%   max
# DP02_0068PE  576.0  17.931424  10.421992   2.1  10.700  15.20  21.775  60.8
# DP02_0072PE  576.0  17.298611   6.282602   1.7  12.800  16.45  21.300  51.3
# DP02_0154PE  576.0  72.939583  14.170874  20.5  63.875  76.25  83.400  97.6

# %%
import pandas as pd
df_04 = pd.read_csv(r"C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\Data\ACS\county_subdivision\DP_04.csv", low_memory=False)
other = df_04[['NAME','DP04_0058PE','DP04_0014PE']]

# %%
other.describe().transpose()
# Out:
#              count       mean        std  min  25%   50%     75%   max
# DP04_0058PE  576.0   8.294444   7.457334  0.0  3.1   5.9  11.000  44.4
# DP04_0014PE  576.0  20.947569  14.659794  0.0  9.7  19.5  30.325  76.2

# %%
data = pd.read_csv(r"C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\Data\merged dataset\data_for_R3.csv")

# %%
eco['NAME'] = eco['NAME'].str.replace(', Louisiana', '')
eco['NAME'] = eco['NAME'].str.rstrip()

dis['NAME'] = dis['NAME'].str.replace(', Louisiana', '')
dis['NAME'] = dis['NAME'].str.rstrip()

other['NAME'] = other['NAME'].str.replace(', Louisiana', '')
other['NAME'] = other['NAME'].str.rstrip()
# Out:
# C:\Users\ta444503\AppData\Local\Temp/ipykernel_16832/2210884800.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eco['NAME'] = eco['NAME'].str.replace(', Louisiana', '')
# C:\Users\ta444503\AppData\Local\Temp/ipykernel_16832/2210884800.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eco['NAME'] = eco['NAME'].str.rstrip()
# C:\Users\ta444503\AppData\Local\Temp/ipykernel_16832/2210884800.py:4: SettingWithCopyWarning:
# ...

# %%
eco.rename(columns={'NAME':'County_subdivision'}, inplace=True)
eco.loc[eco['County_subdivision'] == 'New Orleans city, Orleans Parish', 'County_subdivision'] = 'New Orleans, Orleans Parish'

dis.rename(columns={'NAME':'County_subdivision'}, inplace=True)
dis.loc[dis['County_subdivision'] == 'New Orleans city, Orleans Parish', 'County_subdivision'] = 'New Orleans, Orleans Parish'

other.rename(columns={'NAME':'County_subdivision'}, inplace=True)
other.loc[other['County_subdivision'] == 'New Orleans city, Orleans Parish', 'County_subdivision'] = 'New Orleans, Orleans Parish'
# Out:
# C:\Users\ta444503\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# C:\Users\ta444503\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
dff = data.merge(eco,  on = ['County_subdivision'])

# %%
dff2 = dff.merge(dis, on=['County_subdivision'])

# %%
dff3 = dff2.merge(other, on = ['County_subdivision'])

# %%
dff.shape
# Out:
# (166, 17)

# %%
dff3.shape
# Out:
# (166, 22)

# %%
dff3.columns
# Out:
# Index(['County_subdivision', 'a', 'Y', 'b', 'c', 'd', 'e', 'f', 'sub',
#        'County', 'coun', 'Housings', 'House_age', 'Hispanic', 'DP03_0002PE',
#        'DP03_0025E', 'DP03_0136PE', 'DP02_0068PE', 'DP02_0072PE',
#        'DP02_0154PE', 'DP04_0058PE', 'DP04_0014PE'],
#       dtype='object')

# %%
dff3.loc[dff3.County_subdivision == 'District 1, Cameron Parish', 'DP03_0025E'] = 29.1
dff3.loc[dff3.County_subdivision == 'District 6, Cameron Parish', 'DP03_0025E'] = 29.1

# %%
dff3.rename(columns={'DP03_0002PE':'Not_jobless'}, inplace=True)
dff3.rename(columns={'DP03_0025E':'Commute_time'}, inplace=True)
dff3.rename(columns={'DP03_0136PE':'Below_poverty'}, inplace=True)
dff3.rename(columns={'DP02_0068PE':'Bachelor'}, inplace=True)
dff3.rename(columns={'DP02_0072PE':'Disability'}, inplace=True)
dff3.rename(columns={'DP02_0154PE':'Internet'}, inplace=True)
dff3.rename(columns={'DP04_0058PE':'No_vehicle'}, inplace=True)
dff3.rename(columns={'DP04_0014PE':'Mobile_home'}, inplace=True)

# %%
dff3.describe().transpose()
# Out:
#                count          mean           std           min           25%  \
# a              166.0    490.071290   1202.943983      0.500000      4.410347
# Y              166.0      3.189836      2.815119      0.100935      1.038939
# b              166.0     12.487952      9.133513      0.000000      3.000000
# c              166.0   4051.813011   7045.784507      0.000000    661.649405
# d              166.0     67.630501     55.064340      5.734607     30.813516
# e              166.0  53791.481928  19837.677451  16583.000000  39588.000000
# f              166.0     29.695181     23.732734      0.000000     10.125000
# sub            166.0     82.500000     48.064193      0.000000     41.250000
# coun           166.0     18.759036      9.561400      0.000000     11.000000
# Housings       166.0   6088.530120  15947.890415    143.000000   1362.250000
# House_age      166.0     72.522892     17.959117      0.000000     64.600000
# ...

# %%
import seaborn as sns
cor2 = dff3.corr()
#plt.subplots(figsize=(10,10))
plt.figure(figsize=(17,17))
sns.heatmap(cor2,annot=True,cmap="coolwarm")
plt.show()

# %%
dff3.columns
# Out:
# Index(['County_subdivision', 'a', 'Y', 'b', 'c', 'd', 'e', 'f', 'sub',
#        'County', 'coun', 'Housings', 'House_age', 'Hispanic', 'Not_jobless',
#        'Commute_time', 'Below_poverty', 'Bachelor', 'Disability', 'Internet',
#        'No_vehicle', 'Mobile_home'],
#       dtype='object')

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
  
# the independent variables set
X = dff3[['Duration of road blockage', 'Restoration time for power outage', 'Property damage',
         'Dist. to Hurricane Path','Income','Black','Hispanic','House_age']]
  
# VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
  
# calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]

# %%
dff3.to_csv(r"C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\Data\merged dataset\Data_for_R4_withoutsvi.csv",index=False)

# %%
fig, ax = plt.subplots(figsize=(7, 6))
plt.hist(irma['Time'], bins =9, edgecolor = "black", align='mid')
plt.xlabel("Restoration time (Days)", size = 10,**csfont)
plt.ylabel("Number of counties", size = 10, **csfont)
#plt.title("Distribution of restoration time for power outage", fontsize = 11,**csfont)
plt.xticks(fontname = "Times New Roman")
plt.yticks(fontname = "Times New Roman")
#ax = plt.figure().gca()
ax.yaxis.set_major_locator(MaxNLocator(integer=True))

#plt.xticks(range(11))
#plt.grid()
#a_plot.set(ylim=(0, 20))
#plt.ticklabel_format(style='int', axis='y')
#plt.subplots_adjust(top=0.8)
plt.savefig("Histogram.png",dpi=600,bbox_inches='tight')

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
#data = sm.datasets.get_rdataset('dietox', 'geepack').data
#md = smf.mixedlm("Weight ~ Time", data, groups=data["Pig"], re_formula="~Time")
md = smf.mixedlm("Y ~ a + b + c + d + e +f",
        data = seven, groups= seven["sub"])
mdf = md.fit(method=["lbfgs"])
print(mdf.summary())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sub'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
import statsmodels.api as sm

import statsmodels.formula.api as smf

data = sm.datasets.get_rdataset("dietox", "geepack").data

md = smf.mixedlm("Weight ~ Time", data, groups=data["Pig"])

mdf = md.fit()

print(mdf.summary())
# Out:
#          Mixed Linear Model Regression Results
# ...
# Model:            MixedLM Dependent Variable: Weight
# No. Observations: 861     Method:             REML
# No. Groups:       72      Scale:              11.3669
# Min. group size:  11      Log-Likelihood:     -2404.7753
# Max. group size:  12      Converged:          Yes
# Mean group size:  12.0
# --------------------------------------------------------
#              Coef.  Std.Err.    z    P>|z| [0.025 0.975]
# --------------------------------------------------------
# Intercept    15.724    0.788  19.952 0.000 14.179 17.268
# Time          6.943    0.033 207.939 0.000  6.877  7.008
# Group Var    40.394    2.149
# ...

# %%
data.head()
# Out:
#     Pig     Evit     Cu  Litter  Start    Weight       Feed  Time
# 0  4601  Evit000  Cu000       1   26.5  26.50000        NaN     1
# 1  4601  Evit000  Cu000       1   26.5  27.59999   5.200005     2
# 2  4601  Evit000  Cu000       1   26.5  36.50000  17.600000     3
# 3  4601  Evit000  Cu000       1   26.5  40.29999  28.500000     4
# 4  4601  Evit000  Cu000       1   26.5  49.09998  45.200001     5

# %%
#Load Georgia dataset and generate plot of Georgia counties (figure 1)
#georgia_data = pd.read_csv(r"C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\irma\new data\gwr\actual_counties.csv")
import geopandas as gpd
georgia_shp = gpd.read_file(r"C:\Users\ta444503\OneDrive - Knights - University of Central Florida\Desktop\Spring 2022\Algorithm\ida\tl_2016_22_cousub\tl_2016_22_cousub.shp")

# %%
georgia_shp.crs
# Out:
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# ...

# %%
from geopy.geocoders import Nominatim
locator = Nominatim(user_agent="my_user_agent")
location = locator.geocode("2900 Claire Street,Lake Isabella,California,USA")

# %%
import requests

response = requests.get('https://maps.googleapis.com/maps/api/geocode/json?address=1600+Amphitheatre+Parkway,+Mountain+View,+CA')

resp_json_payload = response.json()

#print(resp_json_payload['results'][0]['geometry']['location'])

# %%
resp_json_payload
# Out:
# {'error_message': 'You must use an API key to authenticate each request to Google Maps Platform APIs. For additional information, please refer to http://g.co/dev/maps-no-account',
#  'results': [],
#  'status': 'REQUEST_DENIED'}

# %%
location
# Out:
# Location(2900, Claire Street, Lake Isabella, Kern County, California, 93240, United States, (35.614959, -118.47519100000001, 0.0))
